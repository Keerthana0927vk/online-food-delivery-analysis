# %%
from sqlalchemy import create_engine

# Replace with your MySQL credentials
username = "root"
password = "Keerthana7886@"
host = "localhost"
database = "online_food_delivery_db"

engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}/{database}")

print("Connected to MySQL Successfully ✅")
# Out:
# Connected to MySQL Successfully ✅

# %%
import pandas as pd

df = pd.read_csv("../data/processed/cleaned_online_food_delivery.csv")

print("Dataset ready for upload ✅")
print(df.shape)
# Out:
# Dataset ready for upload ✅
# (98986, 30)

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus("Keerthana7886@")

engine = create_engine(
    f"mysql+pymysql://root:{password}@127.0.0.1:3306/online_food_delivery_db"
)

print("Connected to MySQL Successfully ✅")
# Out:
# Connected to MySQL Successfully ✅

# %%
df.to_sql(
    name="online_food_orders",
    con=engine,
    if_exists="replace",
    index=False
)

print("Data uploaded to MySQL successfully ✅")
# Out:
# Data uploaded to MySQL successfully ✅
